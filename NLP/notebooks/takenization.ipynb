# %%
corpus="""
The quick brown fox jumps over the lazy dog.
The lazy dog was not happy about it.
The fox was quick and agile!
The dog was slow and lazy, but it was loyal.
The fox and the dog had a long history of rivalry."""

# %%
corpus
# Out:
# '\nThe quick brown fox jumps over the lazy dog.\nThe lazy dog was not happy about it.\nThe fox was quick and agile!\nThe dog was slow and lazy, but it was loyal.\nThe fox and the dog had a long history of rivalry.'

# %%
print(corpus)
# Out:
# The quick brown fox jumps over the lazy dog.
# The lazy dog was not happy about it.
# The fox was quick and agile!
# The dog was slow and lazy, but it was loyal.
# The fox and the dog had a long history of rivalry.

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['\nThe quick brown fox jumps over the lazy dog.',
#  'The lazy dog was not happy about it.',
#  'The fox was quick and agile!',
#  'The dog was slow and lazy, but it was loyal.',
#  'The fox and the dog had a long history of rivalry.']

# %%
document=sent_tokenize(corpus)

# %%
for sentence in document:
    print(sentence)
# Out:
# The quick brown fox jumps over the lazy dog.
# The lazy dog was not happy about it.
# The fox was quick and agile!
# The dog was slow and lazy, but it was loyal.
# The fox and the dog had a long history of rivalry.

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog',
#  '.',
#  'The',
#  'lazy',
#  'dog',
#  'was',
#  'not',
#  'happy',
#  'about',
#  'it',
#  '.',
#  'The',
#  'fox',
#  'was',
#  'quick',
#  'and',
#  'agile',
#  '!',
#  'The',
#  'dog',
#  'was',
#  'slow',
#  'and',
#  'lazy',
#  ',',
#  'but',
#  'it',
#  'was',
#  'loyal',
#  '.',
#  'The',
#  'fox',
#  'and',
#  'the',
#  'dog',
#  'had',
#  'a',
#  'long',
#  'history',
#  'of',
#  'rivalry',
#  '.']

# %%
for sentence in document:
    print(word_tokenize(sentence))
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.']
# ['The', 'lazy', 'dog', 'was', 'not', 'happy', 'about', 'it', '.']
# ['The', 'fox', 'was', 'quick', 'and', 'agile', '!']
# ['The', 'dog', 'was', 'slow', 'and', 'lazy', ',', 'but', 'it', 'was', 'loyal', '.']
# ['The', 'fox', 'and', 'the', 'dog', 'had', 'a', 'long', 'history', 'of', 'rivalry', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog',
#  '.',
#  'The',
#  'lazy',
#  'dog',
#  'was',
#  'not',
#  'happy',
#  'about',
#  'it',
#  '.',
#  'The',
#  'fox',
#  'was',
#  'quick',
#  'and',
#  'agile',
#  '!',
#  'The',
#  'dog',
#  'was',
#  'slow',
#  'and',
#  'lazy',
#  ',',
#  'but',
#  'it',
#  'was',
#  'loyal',
#  '.',
#  'The',
#  'fox',
#  'and',
#  'the',
#  'dog',
#  'had',
#  'a',
#  'long',
#  'history',
#  'of',
#  'rivalry',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog.',
#  'The',
#  'lazy',
#  'dog',
#  'was',
#  'not',
#  'happy',
#  'about',
#  'it.',
#  'The',
#  'fox',
#  'was',
#  'quick',
#  'and',
#  'agile',
#  '!',
#  'The',
#  'dog',
#  'was',
#  'slow',
#  'and',
#  'lazy',
#  ',',
#  'but',
#  'it',
#  'was',
#  'loyal.',
#  'The',
#  'fox',
#  'and',
#  'the',
#  'dog',
#  'had',
#  'a',
#  'long',
#  'history',
#  'of',
#  'rivalry',
#  '.']
